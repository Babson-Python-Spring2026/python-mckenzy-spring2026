# %% [markdown]
# # Homework — Loops, Functions, and Imports
#
# **Graded Assignment — Read Carefully**
#
# This homework emphasizes **reasoning, prediction, and explanation**, not just producing output.
#
# ## Rules
# - Do **not** run code until instructed.
# - For every problem:
#   1. Write your **prediction**
#   2. Write a **brief explanation** (1–3 sentences)
#   3. Then run and compare
#
# Partial credit is awarded for clear reasoning, even if the prediction is incorrect.

# %% [markdown]
# ## Part A — Loops (8 problems)

# %% [markdown]
# ### Problem 1 — Accumulator with condition
# Predict the final value of `total`.
# ```python
# nums = [3, 6, 2, 5, 4]
# total = 0
# for n in nums:
#     if n % 2 == 0:
#         total += n
#     else:
#         total -= 1
# print(total)
# ```
# Explain *why*.

# %%
nums = [3, 6, 2, 5, 4]
total = 0
for n in nums:
    if n % 2 == 0:
        total += n
    else:
        total -= 1
print(total)

# Prediction:
'''
I beleive that the final total will be 10.
'''
# Explanation:
'''
Only even numbers were added and for every odd number 1 was subtracted from the total which
resulted in 10.
'''
# Out:
# 10
# '\nOnly even numbers were added and for every odd number 1 was subtracted from the total which\nresulted in 10.\n'

# %% [markdown]
# ### Problem 2 — Nested loops with dependent ranges
# Predict the exact output.
# ```python
# for i in range(1, 4):
#     for j in range(i):
#         print(i, end=" ")
#     print()
# ```

# %%
for i in range(1, 4):
    for j in range(i):
        print(i, end=" ")
    print()

# Prediction:
'''
I think that the output will be 1
                                2 2  
                                3 3 3
'''
# Explanation:
'''
For each value between 1 and 4(excluding 4), 
i will be printed the same number of times as its value(i will be printed i times). This is due to the
nested for loop structure of the code.
This results in one 1, two 2s and three 3s being printed
'''
# Out:
# 1
# 2 2
# 3 3 3
# '\nI think that the output will be 1 1\n                                2 2 2  \n                                3 3 3\n'

# %% [markdown]
# ### Problem 3 — Loop with early termination
# Predict the output.
# ```python
# for n in range(2, 20):
#     if n % 7 == 0:
#         print("hit", n)
#         break
#     print(n)
# ```

# %%
for n in range(2, 20):
    if n % 7 == 0:
        print("hit", n)
        break
    print(n)


# Prediction:
'''
I think the printed statement will be:
2 3 4 5 6 hit 7
'''

# Explanation:
'''
The code above starts at 2 and prints 2 and its following numbers up to 20(excluding 20).
The if statement checks each value of n to see if n%7 == 0.
If the conditions are not met then the number is just printed but if it is met then the loop breaks
and a different print statement is executed. 
Each number is printed on its own line and that the loop stops immediately after hitting 7.

'''
# Out:
# 2
# 3
# 4
# 5
# 6
# hit 7
# '\nI think the printed statement will be:\n2 3 4 5 6 hit 7 8 9 10 11 12 13 hit 14 15 16 17 18 19\n'

# %% [markdown]
# ### Problem 4 — Loop invariant
# State the loop invariant for `total` *before* predicting the output.
# ```python
# nums = [5, 1, 4, 2]
# total = 0
# for n in nums:
#     total = max(total, n)
# print(total)
# ```

# %%
nums = [5, 1, 4, 2]
total = 0
for n in nums:
    total = max(total, n)
print(total)

# Prediction:
'''
The invariant is that at the start of each iteration, total equals 
the maximum value seen so far in the list.
I beleive that the output will be the maxim value in the list: 5
'''
# Explanation:
'''
The code compares each number on the list to the value of total which is 0 in this case.
Then a new object for total is created and that new object holds the new value of total 
which could be the original value which was initialized or a new value derived from the max operation.
In other words,At each iteration, total is updated to the maximum of its current value and the current 
element of the list.
'''
# Out:
# 5
# '\nThe invariant for total is that it cannot be greater than the maximum value in the list.\nI beleive that the output will be the maxim value in the list: 5\n'

# %% [markdown]
# ### Problem 5 — Off-by-one reasoning
# Predict the output.
# ```python
# count = 0
# for i in range(1, 10):
#     if i % 3 == 0:
#         count += 1
# print(count)
# ```

# %%
count = 0
for i in range(1, 10):
    if i % 3 == 0:
        count += 1
print(count)

# Prediction:
'''
I beleive that the number 3 will be printed
'''
# Explanation:
'''
At first count is initialized to 0. Then the for loop counts from numbers 1 to 10(excuding 10)
and checks if each number hes a remainder of 0 when divided by 3. If the condition is met then
count increases by 1. Numbers 3,6, and 9 meet the criteria of the if statement so the count is 3.
'''
# Out:
# 3
# '\nI beleive that the output will be 3\n'

# %% [markdown]
# ### Problem 6 — Nested loop with break
# Predict the output.
# ```python
# for i in range(3):
#     for j in range(3):
#         if i == j:
#             break
#         print(i, j)
# ```

# %%
for i in range(3):
    for j in range(3):
        if i == j:
            break
        print(i, j)

# Prediction:
'''
I think that the output will be 1 0
                                2 0
                                2 1
'''
# Explanation:
'''
Each of the loops count from 0 to 3(excluding 3). For each value of i, j will cound up within the
same range and only the combaniation of numbers that are not homogenous will be printed. If the
pair of numbers is homogenous then the print stamement is not executed.
'''
# Out:
# 1 0
# 2 0
# 2 1
# '\nI think that the output will be 1 0\n                                2 0\n                                2 1\n'

# %% [markdown]
# ### Problem 7 — While loop with state change
# Predict the output and number of iterations.
# ```python
# x = 20
# while x > 1:
#     if x % 2 == 0:
#         x //= 2
#     else:
#         x -= 1
#     print(x)
# ```

# %%
x = 20
while x > 1:
    if x % 2 == 0:
        x //= 2
    else:
        x -= 1
    print(x)

# Prediction:
'''
I beleive that the number of itterations will be 5 and I think that the output will be: 10 5 4 2 1
'''
# Explanation:
'''
The function take the starting value of of x and checks to see if is greater than 1.
If it is true then another condition is checked and this is to see if the value of x is divisible by 2.
If these 2 conditions are met then the value of x is changed to the quocient of x divided by 2.
If only the first considion is met then x just counts down by 1.

'''
# Out:
# 10
# 5
# 4
# 2
# 1
# '\nI beleive that the number of itterations will be 5\n\nI beleive that the output will be: 10 5 4 2 1\n'

# %% [markdown]
# ### Problem 8 — Trick loop (mutation during iteration)
# Predict the final list.
# ```python
# nums = [1, 2, 3, 4]
# for i in range(len(nums)):
#     if nums[i] % 2 == 0:
#         nums[i] *= 10
# print(nums)
# ```

# %%
nums = [1, 2, 3, 4]
for i in range(len(nums)):
    if nums[i] % 2 == 0:
        nums[i] *= 10
print(nums)

# Prediction:
'''
I think that the final list will be [1,20,3,40]
'''
# Explanation:
'''
The for loop runs for the entire length of the list and it checks each value in the list to see if it
is an even number. If the number is even then due to lists mutable property the original list is mutated
and the value if multiplied by 10. If the value is odd then the no operations are executed.
'''
# Out:
# [1, 20, 3, 40]
# '\nI think that the final list will be [1,20,3,40]\n'

# %% [markdown]
# ## Part B — Functions (7 problems)

# %% [markdown]
# ### Problem 9 — Parameter binding
# Predict the output and explain parameter binding.
# ```python
# def f(a, b=2, c=3):
#     return a + b*10 + c*100
# print(f(1, 4))
# ```

# %%
def f(a, b=2, c=3):
    return a + b*10 + c*100
print(f(1, 4))

# Prediction:
'''
I think that the ouput will be 341
'''
# Explanation:
'''
The inputs into the function are 1 for a and 4 for b. Because there is no explicit input for c
the default value of 3 is used. After doing the operations(1 + 40 + 300), 341 is the final result.

'''
# Out:
# 341
# '\nI think that the ouput will be 81\n'

# %% [markdown]
# ### Problem 10 — Keyword vs positional
# Predict all outputs.
# ```python
# def g(x, y=5, z=7):
#     return x, y, z
# print(g(1))
# print(g(1, z=9))
# print(g(1, 9))
# ```

# %%
def g(x, y=5, z=7):
    return x, y, z
print(g(1))
print(g(1, z=9))
print(g(1, 9))

# Prediction:
'''
I beleive that the 3 outputs will be:
1 5 7 
1 5 9
1 9 7
'''
# Explanation:
'''
In the first print statement 1 becaome the value of x and all default values are retained.
In the second statement 1 take the value of x and 9 takes the value of z because it is specified and the value of y remains constant.
In the third statement 1 takes the value of x and 9 takes the value of y and z stays constant.
'''
# Out:
# (1, 5, 7)
# (1, 5, 9)
# (1, 9, 7)
# '\nI beleive that the 3 outputs will be:\n1 5 7 \n1 5 9\n1 9 7\n'

# %% [markdown]
# ### Problem 11 — Mutable argument (mutation)
# Does the caller’s list change? Why?
# ```python
# def update(nums):
#     nums.append(99)
# a = [1, 2, 3]
# update(a)
# print(a)
# ```

# %%
def update(nums):
    nums.append(99)
a = [1, 2, 3]
update(a)
print(a)

# Prediction:
'''
 The output will be: 1 2 3 99
'''
# Explanation:
'''
The callers list changes because lits are mutable. as a result the update function adds
the number 99 to the end of the list.

'''
# Out:
# [1, 2, 3, 99]
# '\nThe callers list changes because lits are mutable. as a result the update function adds\nthe number 99 to the end of the list.\n\n'

# %% [markdown]
# ### Problem 12 — Mutable argument (reassignment)
# Does the caller’s list change? Why?
# ```python
# def update(nums):
#     nums = nums + [99]
# a = [1, 2, 3]
# update(a)
# print(a)
# ```

# %%
def update(nums):
    nums = nums + [99]
a = [1, 2, 3]
update(a)
print(a)

# Prediction:
'''
The output will be: 1 2 3
'''
# Explanation:
'''
No, the callers list does not change because a list is created(reassignment) and the original list
is not modified.
'''
# Out:
# [1, 2, 3]
# '\nNo, the callers list does not change because a list is created and the original list\nis not modified.\n'

# %% [markdown]
# ### Problem 13 — Default parameter trap
# Predict the outputs.
# ```python
# def add_item(item, bucket=[]):
#     bucket.append(item)
#     return bucket
# print(add_item(1))
# print(add_item(2))
# ```

# %%
def add_item(item, bucket=[]):
    bucket.append(item)
    return bucket
print(add_item(1))
print(add_item(2))

# Prediction:
'''
I think that the output will be: 1 and 1 2

'''
# Explanation:
'''
The function adds each input into a list. The first use of the function adds 1 to the empty list and
the second list function adds 2 to the muttable list.
'''
# Out:
# [1]
# [1, 2]
# '\nI think that the output will be: 1 and 1 2\n\n'

# %% [markdown]
# ### Problem 14 — Return vs print
# Predict the output.
# ```python
# def h(x):
#     print(x + 1)
# result = h(5)
# print(result)
# ```

# %%
def h(x):
    print(x + 1)
result = h(5)
print(result)

# Prediction:
'''
I think that the output will be: 6 and none
'''
# Explanation:
'''
6 is printed because the operation adds 1 to the input of 5. Non is printed because there is no
return statement in the function
'''
# Out:
# 6
# None
# '\nI think that the output will be: 6\n'

# %% [markdown]
# ### Problem 15 — Function invariant
# What invariant must hold for `total`? Predict the output.
# ```python
# def sum_positive(nums):
#     total = 0
#     for n in nums:
#         if n > 0:
#             total += n
#     return total
# print(sum_positive([-1, 2, -3, 4]))
# ```

# %%
def sum_positive(nums):
    total = 0
    for n in nums:
        if n > 0:
            total += n
    return total
print(sum_positive([-1, 2, -3, 4]))

# Prediction:
'''
I think the at the output will be: 6
'''
# Explanation:
'''
The function has a condition that only positive numbers are added
and the list has 2 and 4 as positive numbers. The sum of 2 and 4 is 6.

The invariant is that at the beginning of each loop iteration, total equals the sum
of all positive numbers encountered so far.
'''
# Out:
# 6
# '\nI think the at the output will be: 6\n'

# %% [markdown]
# ## Part C — Imports (5 problems)

# %% [markdown]
# ### Problem 16 — Syntax vs importability
# Which lines are **valid syntax**? Which will **run successfully**? Explain.
# ```python
# from packages.utils import helper
# from packages/utils import helper
# import packages.utils
# ```

# %%
# Explanation:
'''
Lines 1 and 3 are valid syntax. The lined will run only if the 
package and module exist and are discoverable in Python’s path.
'''

# %% [markdown]
# ### Problem 17 — `sys.path` reasoning
# Explain why the blank entry (`''`) may appear in `sys.path` and what it represents.

# %%
# Explanation:
'''
The empty string '' in sys.path represents the current working directory.
It allows Python to search for modules in the directory from which the script
was executed (or where the interpreter was started)
'''

# %% [markdown]
# ### Problem 18 — Package resolution
# Given:
# ```
# root/
#   src/
#     main.py
#   packages/
#     utils.py
# ```
# What directory must be on `sys.path` for this to work?
# ```python
# from packages import utils
# ```

# %%
# Explanation:
'''
Root/ much be on sys.path for it to work. This is because Python searched for the 
package name inside each directory listed inside of sys.path. Since packages in inside of root
the directory is needed for the imprt to work.
'''

# %% [markdown]
# ### Problem 19 — Incorrect path placement
# Why does adding `root/packages` to `sys.path` break this import?
# ```python
# from packages import utils
# ```

# %%
# Explanation:
'''
This would break the import because looks for the package named packages
inside the directories in sys.path. If root/packages is on sys.path.
Python will look for root/packages/packages, which does not exist.
'''

# %% [markdown]
# ### Problem 20 — Notebook vs `.py` anchoring
# Explain why notebooks typically use `Path.cwd()` while `.py` files use `Path(__file__)`.

# %%
# Explanation:
'''
Notebooks use Path.cwd() because they do not have file properties so they need to be
attatched to the current working directory.
.py files use Path(__file__) because file gives the location of the script. This allows
paths to be constructed relative to the script’s directory rather than the execution location.

'''
